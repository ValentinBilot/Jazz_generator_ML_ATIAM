# %% [markdown]
# # Cellule d'entraînement
# Il faut que le modèle existe pour pouvoir l'entraîner, afin de ne pas écraser par erreur des modèles entraînés, un autre fichier est (sera) disponible pour créer le modèle en question avant de l'entaîner
#
# ## Choix des paramètres:
#
#
# Attention ce notebook est encore en développement, pour l'instant les paramètres disponibles sont :
#
#     - optimizer : Adam
#     - lossFunction : CrossEntropy
#     - model_type : rnn, lstm, gru
#     - alphabet : a0

# %%
params = {
        'print_every': 1,
        'plot_every': 1,
        'optimizer': "Adam",
        'lossFunction': "CrossEntropy",
        'model_type': "rnn",
        'alphabet': 'a0',
        'sequence_lenght': 16, 
        'using_cuda': True,
        'batch_size': 128,
        'shuffle': True, 
        'num_workers': 6,
        'hidden_size': 512,
        'num_layers': 2,
        'dropout': 0.1,
        'learning_rate': 1e-4, 
        'epochs': 10}

from GRUClass import MYGRU
from RNNClass import MYRNN
from LSTMClass import MYLSTM
import torch

dropout = params['dropout']
model_type = params['model_type']
num_layers = params['num_layers']
hidden_size = params['hidden_size']
alphabet = params['alphabet']
sequence_lenght = params['sequence_lenght']
dropoutstr = str(dropout).replace('.',',')
model_string = "models/"+model_type+str(num_layers)+"layers"+str(hidden_size)+"blocks"+alphabet+"alphabet"+str(sequence_lenght)+"lenSeq"+dropoutstr+"dropout.pt"

if params['alphabet'] == "a0":
    alphabet_size = 25

# %% [markdown]
# ## Create a new network or load an old one
#
# ### Create :

# %%
if model_type == "gru":
    myNetwork = MYGRU(alphabet_size, hidden_size, num_layers, dropout)
elif model_type == "lstm":
    myNetwork = MYLSTM(alphabet_size, hidden_size, num_layers, dropout)
elif model_type == "rnn":
    myNetwork = MYRNN(alphabet_size, hidden_size, num_layers, dropout)

# %% [markdown]
# ### Load :

# %%
myNetwork = torch.load(model_string)

# %% [markdown]
# # Train and Test the Network on the RealBook dataset

# %%
myNetwork.trainAndTest(**params)
# Out:
# Trying using Cuda ...
# OK
# Start training
# Train : 0m 0s (1 10%) loss : 0.0285, accuracy : 25.6741%
# Test : 0m 1s (1 10%) loss : 0.0341, accuracy : 29.8043%
# Train : 0m 1s (2 20%) loss : 0.0310, accuracy : 28.0188%
# Test : 0m 2s (2 20%) loss : 0.0314, accuracy : 32.1124%
# Train : 0m 2s (3 30%) loss : 0.0287, accuracy : 32.4736%
# Test : 0m 3s (3 30%) loss : 0.0360, accuracy : 28.2489%
# Train : 0m 4s (4 40%) loss : 0.0261, accuracy : 28.0188%
# Test : 0m 4s (4 40%) loss : 0.0324, accuracy : 28.1987%
# Train : 0m 5s (5 50%) loss : 0.0280, accuracy : 30.5979%
# Test : 0m 6s (5 50%) loss : 0.0323, accuracy : 29.1520%
# Train : 0m 6s (6 60%) loss : 0.0273, accuracy : 31.7702%
# Test : 0m 7s (6 60%) loss : 0.0323, accuracy : 31.5103%
# Train : 0m 8s (7 70%) loss : 0.0282, accuracy : 30.8324%
# Test : 0m 8s (7 70%) loss : 0.0313, accuracy : 32.8149%
# Train : 0m 9s (8 80%) loss : 0.0271, accuracy : 34.3494%
# Test : 0m 9s (8 80%) loss : 0.0291, accuracy : 32.9152%
# Train : 0m 10s (9 90%) loss : 0.0265, accuracy : 32.3564%
# Test : 0m 11s (9 90%) loss : 0.0345, accuracy : 33.9689%
# Finished Training

# %% [markdown]
# # Training and testing results

# %%
myNetwork.plotLastTraining()

# %% [markdown]
# # Save the Model

# %%
torch.save(myNetwork,myNetwork.toString(**params))
print("model saved as : "+myNetwork.toString(**params))
# Out:
# model saved as : models/rnn2layers512blocksa0alphabet16lenSeq0,1dropout.pt

# %% [markdown]
# # Results of all training sessions
# Si une courbe n'apparait pas, c'est sûrement qu'elle est d'une couleur trop claire.

# %%
myNetwork.plotAllTraining()
# Out:
# ['royalblue', 'tomato']
