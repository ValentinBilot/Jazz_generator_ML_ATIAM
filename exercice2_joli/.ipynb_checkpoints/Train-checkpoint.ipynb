# %% [markdown]
# # Cellule d'entraînement
# Il faut que le modèle existe pour pouvoir l'entraîner, afin de ne pas écraser par erreur des modèles entraînés, un autre fichier est (sera) disponible pour créer le modèle en question avant de l'entaîner
#
# ## Choix des paramètres:
#
#
# Attention ce notebook est encore en développement, pour l'instant les paramètres disponibles sont :
#
#     - optimizer : Adam
#     - lossFunction : CrossEntropy
#     - model_type : rnn, lstm, gru
#     - alphabet : a0, a1, a2, a3, a5

# %%
params = {
        'print_every': 10,
        'plot_every': 10,
        'optimizer': "Adam",
        'lossFunction': "CrossEntropy",
        'model_type': "rnn",
        'alphabet': 'a0',
        'sequence_lenght': 16, 
        'using_cuda': True,
        'batch_size': 512,
        'shuffle': True, 
        'num_workers': 6,
        'hidden_size': 512,
        'num_layers': 2,
        'dropout': 0.1,
        'learning_rate': 5e-4, 
        'epochs': 50,
        'use_Paul_distance': True}

from GRUClass import MYGRU
from RNNClass import MYRNN
from LSTMClass import MYLSTM
import torch
import os
from utilities import chordUtil
from utilities.chordUtil import *


dropout = params['dropout']
model_type = params['model_type']
num_layers = params['num_layers']
hidden_size = params['hidden_size']
alphabet = params['alphabet']
sequence_lenght = params['sequence_lenght']
dropoutstr = str(dropout).replace('.',',')
model_string = "models/"+model_type+str(num_layers)+"layers"+str(hidden_size)+"blocks"+alphabet+"alphabet"+str(sequence_lenght)+"lenSeq"+dropoutstr+"dropout.pt"


# Getting alphabet size :
rootname = "inputs/jazz_xlab/"
filenames = os.listdir(rootname)
dictChord, listChord = chordUtil.getDictChord(eval(alphabet))
alphabet_size = len(dictChord)
print(dictChord)
# Out:
# {'B:min': 0, 'A:maj': 1, 'C#:min': 2, 'A#:min': 3, 'C:min': 4, 'D:maj': 5, 'B:maj': 6, 'F#:maj': 7, 'N': 8, 'A:min': 9, 'G:min': 10, 'F:min': 11, 'E:maj': 12, 'F:maj': 13, 'D:min': 14, 'G#:maj': 15, 'A#:maj': 16, 'D#:maj': 17, 'E:min': 18, 'C:maj': 19, 'D#:min': 20, 'G#:min': 21, 'C#:maj': 22, 'G:maj': 23, 'F#:min': 24}

# %% [markdown]
# ## Create a new network or load a trained one
#
# ### Create :

# %%
if model_type == "gru":
    myNetwork = MYGRU(alphabet_size, hidden_size, num_layers, dropout)
elif model_type == "lstm":
    myNetwork = MYLSTM(alphabet_size, hidden_size, num_layers, dropout)
elif model_type == "rnn":
    myNetwork = MYRNN(alphabet_size, hidden_size, num_layers, dropout)

# %% [markdown]
# ### Load :

# %%
myNetwork = torch.load(model_string)

# %% [markdown]
# # Train and Test the Network on the RealBook dataset

# %%
myNetwork.trainAndTest(**params)
# Out:
# Trying using Cuda ...
# OK
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-038b423401f5> in <module>()
# ----> 1 myNetwork.trainAndTest(**params)
#
# ~/Documents/ATIAM/Jazz_generator_ML_ATIAM/exercice2_joli/RNNClass.py in trainAndTest(self, model_type, print_every, plot_every, optimizer, lossFunction, alphabet, sequence_lenght, using_cuda, batch_size, shuffle, num_workers, hidden_size, num_layers, dropout, learning_rate, epochs, use_Paul_distance)
#      74         start = time.time()
#      75
# ---> 76         all_losses, test_losses, accuracy_train, accuracy_test = self.doEpochs(model_type, epochs, print_every, plot_every, optimizer, lossFunction, learning_rate, batch_size, shuffle, num_workers, alphabet, sequence_lenght, device, start, use_Paul_distance, training=True)
#      77
#      78         self.trainingData[0].append(self.trainingData[0][-1]+1)
#
# ~/Documents/ATIAM/Jazz_generator_ML_ATIAM/exercice2_joli/RNNClass.py in doEpochs(self, model_type, epochs, print_every, plot_every, optimizer, lossFunction, learning_rate, batch_size, shuffle, num_workers, alphabet, sequence_lenght, device, start, use_Paul_distance, training)
#     121         if use_Paul_distance:
#     122             M = chordsDistances.getPaulMatrix()
# --> 123             M = remapChordsToBase.remapPaulToTristan(M,alphabet)
#     124             distance_tensor = torch.tensor(M, dtype = torch.float).to(device)
#     125         else:
#
# ~/Documents/ATIAM/Jazz_generator_ML_ATIAM/exercice2_joli/utilities/remapChordsToBase.py in remapPaulToTristan(PaulBaseMatrix, alphabet)
#      16
#      17     rootname = "../inputs/jazz_xlab/"
# ---> 18     filenames = os.listdir(rootname)
#      19     dictChord, listChord = chordUtil.getDictChord(eval(alphabet))
#      20
#
# FileNotFoundError: [Errno 2] No such file or directory: '../inputs/jazz_xlab/'

# %% [markdown]
# # Training and testing results

# %%
myNetwork.plotLastTraining()

# %% [markdown]
# # Save the Model

# %%
torch.save(myNetwork,myNetwork.toString(**params))
print("model saved as : "+myNetwork.toString(**params))
# Out:
# model saved as : models/lstm2layers512blocksa1alphabet16lenSeq0,1dropout.pt

# %% [markdown]
# # Results of all training sessions
# Si une courbe n'apparait pas, c'est sûrement qu'elle est d'une couleur trop claire.

# %%
myNetwork.plotAllTraining()
# Out:
# ['aqua', 'cornflowerblue', 'honeydew']

# %% [markdown]
# # Training memory :
# Les données relatifs aux entraînements sont stockées dans trainingData

# %%
print(["training number","optimizer used","LossFunction used","train loss","test loss","train accuracy","test accuracy","time"])
print("\n")
print(myNetwork.trainingData)
# Out:
# ['training number', 'optimizer used', 'LossFunction used', 'train loss', 'test loss', 'train accuracy', 'test accuracy', 'time']
#
#
